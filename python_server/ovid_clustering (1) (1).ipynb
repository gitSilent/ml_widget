# %% [markdown]
# # Импорт необходимых библиотек

# %%
import pandas as pd #библиотека для обработки и анализа данных
import matplotlib .pyplot as plt #билиотека для визуализации данных двумерной и трёхмерной графикой.
import numpy as np #библиотека для для выполнения математических и числовых операций
import seaborn as sns #библиотека для создания статистических графиков 
from sklearn.preprocessing import StandardScaler #библиотека метода масштабирования данных
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
# pd.options.display.float_format = '{:,.0f}'.format
pd.options.display.float_format ='{:,.3f}'.format
import datetime
from datetime import timedelta
import math
import json

pd.options.display.max_rows = 2000

# %% [markdown]
# # Загрузка данных

# %%
df_loaded = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv", parse_dates=["date"])
df = df_loaded

# %% [markdown]
# # Предобработка данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320229 entries, 0 to 320228
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    320229 non-null  object
#  1   continent                                   305019 non-null  object
#  2   location                                    320229 non-null  object
#  3   date                                        320229 non-null  datetime64[ns]
#  4   total_cases                                 287547 non-null  float64
#  5   new_cases                                   311310 non-null  float64
#  6   new_cases_smoothed                          310046 non-null  float64
#  7   total_deaths                                269083 non-null  float64
#  8   new_deaths                                  311356 non-null  float64
#  9   new_deaths_smoothed                         310126 non-null  float64
#  10  total_cases_per_million                     287547 non-null  float64
#  11  new_cases_per_million                       311310 non-null  float64
#  12  new_cases_smoothed_per_million              310046 non-null  float64
#  13  total_deaths_per_million                    269083 non-null  float64
#  14  new_deaths_per_million                      311356 non-null  float64
#  15  new_deaths_smoothed_per_million             310126 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                36661 non-null   float64
#  18  icu_patients_per_million                    36661 non-null   float64
#  19  hosp_patients                               37469 non-null   float64
#  20  hosp_patients_per_million                   37469 non-null   float64
#  21  weekly_icu_admissions                       9682 non-null    float64
#  22  weekly_icu_admissions_per_million           9682 non-null    float64
#  23  weekly_hosp_admissions                      22312 non-null   float64
#  24  weekly_hosp_admissions_per_million          22312 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          76204 non-null   float64
#  35  people_vaccinated                           72972 non-null   float64
#  36  people_fully_vaccinated                     69497 non-null   float64
#  37  total_boosters                              44708 non-null   float64
#  38  new_vaccinations                            62707 non-null   float64
#  39  new_vaccinations_smoothed                   172060 non-null  float64
#  40  total_vaccinations_per_hundred              76204 non-null   float64
#  41  people_vaccinated_per_hundred               72972 non-null   float64
#  42  people_fully_vaccinated_per_hundred         69497 non-null   float64
#  43  total_boosters_per_hundred                  44708 non-null   float64
#  44  new_vaccinations_smoothed_per_million       172060 non-null  float64
#  45  new_people_vaccinated_smoothed              171892 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  171892 non-null  float64
#  47  stringency_index                            197651 non-null  float64
#  48  population_density                          271730 non-null  float64
#  49  median_age                                  252725 non-null  float64
#  50  aged_65_older                               243878 non-null  float64
#  51  aged_70_older                               250193 non-null  float64
#  52  gdp_per_capita                              247675 non-null  float64
#  53  extreme_poverty                             159546 non-null  float64
#  54  cardiovasc_death_rate                       248160 non-null  float64
#  55  diabetes_prevalence                         260807 non-null  float64
#  56  female_smokers                              186142 non-null  float64
#  57  male_smokers                                183609 non-null  float64
#  58  handwashing_facilities                      121549 non-null  float64
#  59  hospital_beds_per_thousand                  219058 non-null  float64
#  60  life_expectancy                             294503 non-null  float64
#  61  human_development_index                     240549 non-null  float64
#  62  population                                  320229 non-null  float64
#  63  excess_mortality_cumulative_absolute        11090 non-null   float64
#  64  excess_mortality_cumulative                 11090 non-null   float64
#  65  excess_mortality                            11090 non-null   float64
#  66  excess_mortality_cumulative_per_million     11090 non-null   float64
# dtypes: datetime64[ns](1), float64(62), object(4)
# memory usage: 163.7+ MB

# %%
df.describe().T
# Out:
#                                                  count            mean  \
# total_cases                                287,547.000   5,915,161.456
# new_cases                                  311,310.000      10,458.979
# new_cases_smoothed                         310,046.000      10,499.898
# total_deaths                               269,083.000      80,069.501
# new_deaths                                 311,356.000          93.273
# new_deaths_smoothed                        310,126.000          93.623
# total_cases_per_million                    287,547.000      90,271.593
# new_cases_per_million                      311,310.000         158.007
# new_cases_smoothed_per_million             310,046.000         158.629
# total_deaths_per_million                   269,083.000         807.831
# new_deaths_per_million                     311,356.000           0.990
# new_deaths_smoothed_per_million            310,126.000           0.993
# reproduction_rate                          184,817.000           0.911
# icu_patients                                36,661.000         689.642
# icu_patients_per_million                    36,661.000          16.657
# hosp_patients                               37,469.000       4,020.846
# hosp_patients_per_million                   37,469.000         133.861
# weekly_icu_admissions                        9,682.000         357.092
# weekly_icu_admissions_per_million            9,682.000          10.805
# weekly_hosp_admissions                      22,312.000       4,421.585
# weekly_hosp_admissions_per_million          22,312.000          88.485
# total_tests                                 79,387.000  21,104,573.938
# new_tests                                   75,403.000      67,285.412
# total_tests_per_thousand                    79,387.000         924.255
# new_tests_per_thousand                      75,403.000           3.272
# new_tests_smoothed                         103,965.000     142,178.364
# new_tests_smoothed_per_thousand            103,965.000           2.826
# positive_rate                               95,927.000           0.098
# tests_per_case                              94,348.000       2,403.633
# total_vaccinations                          76,204.000 393,098,110.632
# people_vaccinated                           72,972.000 175,202,779.013
# people_fully_vaccinated                     69,497.000 158,645,334.579
# total_boosters                              44,708.000  97,544,380.147
# new_vaccinations                            62,707.000     832,124.186
# new_vaccinations_smoothed                  172,060.000     319,272.043
# total_vaccinations_per_hundred              76,204.000         115.846
# people_vaccinated_per_hundred               72,972.000          51.213
# people_fully_vaccinated_per_hundred         69,497.000          46.253
# total_boosters_per_hundred                  44,708.000          33.394
# new_vaccinations_smoothed_per_million      172,060.000       2,070.150
# new_people_vaccinated_smoothed             171,892.000     118,114.692
# new_people_vaccinated_smoothed_per_hundred 171,892.000           0.084
# stringency_index                           197,651.000          42.714
# population_density                         271,730.000         409.340
# median_age                                 252,725.000          30.510
# aged_65_older                              243,878.000           8.700
# aged_70_older                              250,193.000           5.500
# gdp_per_capita                             247,675.000      19,006.955
# extreme_poverty                            159,546.000          13.846
# cardiovasc_death_rate                      248,160.000         264.271
# diabetes_prevalence                        260,807.000           8.561
# female_smokers                             186,142.000          10.791
# male_smokers                               183,609.000          32.910
# handwashing_facilities                     121,549.000          50.791
# hospital_beds_per_thousand                 219,058.000           3.097
# life_expectancy                            294,503.000          73.718
# human_development_index                    240,549.000           0.722
# population                                 320,229.000 128,186,736.682
# excess_mortality_cumulative_absolute        11,090.000      48,454.381
# excess_mortality_cumulative                 11,090.000           9.609
# excess_mortality                            11,090.000          12.166
# excess_mortality_cumulative_per_million     11,090.000       1,539.650
#
#                                                          std         min  \
# total_cases                                   36,974,255.273       1.000
# new_cases                                        101,536.916       0.000
# new_cases_smoothed                                98,821.554       0.000
# total_deaths                                     417,655.013       1.000
# new_deaths                                           592.540       0.000
# new_deaths_smoothed                                  583.245       0.000
# total_cases_per_million                          141,358.080       0.000
# new_cases_per_million                              1,116.844       0.000
# new_cases_smoothed_per_million                       626.056       0.000
# total_deaths_per_million                           1,060.239       0.000
# new_deaths_per_million                                 4.622       0.000
# new_deaths_smoothed_per_million                        2.877       0.000
# reproduction_rate                                      0.400      -0.070
# icu_patients                                       2,201.038       0.000
# icu_patients_per_million                              23.223       0.000
# hosp_patients                                     10,147.606       0.000
# hosp_patients_per_million                            154.679       0.000
# weekly_icu_admissions                                535.911       0.000
# weekly_icu_admissions_per_million                     14.030       0.000
# weekly_hosp_admissions                            11,252.249       0.000
# weekly_hosp_admissions_per_million                    90.063       0.000
# total_tests                                   84,098,694.311       0.000
# new_tests                                        247,734.005       1.000
# total_tests_per_thousand                           2,195.429       0.000
# new_tests_per_thousand                                 9.034       0.000
# new_tests_smoothed                             1,138,214.656       0.000
# new_tests_smoothed_per_thousand                        7.308       0.000
# positive_rate                                          0.116       0.000
# tests_per_case                                    33,443.661       1.000
# total_vaccinations                         1,464,826,175.790       0.000
# people_vaccinated                            648,457,728.036       0.000
# people_fully_vaccinated                      594,156,854.345       1.000
# total_boosters                               334,616,428.558       1.000
# new_vaccinations                               3,374,483.435       0.000
# new_vaccinations_smoothed                      2,043,376.794       0.000
# total_vaccinations_per_hundred                        84.408       0.000
# people_vaccinated_per_hundred                         29.907       0.000
# people_fully_vaccinated_per_hundred                   29.556       0.000
# total_boosters_per_hundred                            30.284       0.000
# new_vaccinations_smoothed_per_million              3,253.852       0.000
# new_people_vaccinated_smoothed                   831,132.730       0.000
# new_people_vaccinated_smoothed_per_hundred             0.185       0.000
# stringency_index                                      24.911       0.000
# population_density                                 1,866.756       0.137
# median_age                                             9.084      15.100
# aged_65_older                                          6.094       1.144
# aged_70_older                                          4.135       0.526
# gdp_per_capita                                    19,984.743     661.240
# extreme_poverty                                       20.091       0.100
# cardiovasc_death_rate                                120.928      79.370
# diabetes_prevalence                                    4.941       0.990
# female_smokers                                        10.780       0.100
# male_smokers                                          13.574       7.700
# handwashing_facilities                                31.957       1.188
# hospital_beds_per_thousand                             2.548       0.100
# life_expectancy                                        7.397      53.280
# human_development_index                                0.149       0.394
# population                                   659,921,726.119      47.000
# excess_mortality_cumulative_absolute             141,798.344 -37,726.098
# excess_mortality_cumulative                           12.665     -44.230
# excess_mortality                                      25.993     -95.920
# excess_mortality_cumulative_per_million            1,870.362  -2,142.340
#
#                                                      25%            50%  \
# total_cases                                    6,359.500     61,775.000
# new_cases                                          0.000         14.000
# new_cases_smoothed                                 0.857         35.000
# total_deaths                                     113.000      1,111.000
# new_deaths                                         0.000          0.000
# new_deaths_smoothed                                0.000          0.286
# total_cases_per_million                        1,949.844     21,229.570
# new_cases_per_million                              0.000          1.988
# new_cases_smoothed_per_million                     0.192          9.643
# total_deaths_per_million                          43.739        328.203
# new_deaths_per_million                             0.000          0.000
# new_deaths_smoothed_per_million                    0.000          0.027
# reproduction_rate                                  0.720          0.950
# icu_patients                                      23.000        100.000
# icu_patients_per_million                           2.763          7.295
# hosp_patients                                    205.000        788.000
# hosp_patients_per_million                         35.654         82.032
# weekly_icu_admissions                             26.000        125.000
# weekly_icu_admissions_per_million                  2.174          5.622
# weekly_hosp_admissions                           259.000        921.000
# weekly_hosp_admissions_per_million                27.442         62.824
# total_tests                                  364,654.000  2,067,330.000
# new_tests                                      2,244.000      8,783.000
# total_tests_per_thousand                          43.585        234.141
# new_tests_per_thousand                             0.286          0.971
# new_tests_smoothed                             1,486.000      6,570.000
# new_tests_smoothed_per_thousand                    0.203          0.851
# positive_rate                                      0.017          0.055
# tests_per_case                                     7.100         17.500
# total_vaccinations                         1,527,053.000 11,135,204.500
# people_vaccinated                            866,055.750  5,790,933.500
# people_fully_vaccinated                      800,500.000  5,027,004.000
# total_boosters                               374,516.500  3,821,523.000
# new_vaccinations                               2,978.500     27,314.000
# new_vaccinations_smoothed                        366.000      4,617.500
# total_vaccinations_per_hundred                    36.070        114.785
# people_vaccinated_per_hundred                     24.100         59.370
# people_fully_vaccinated_per_hundred               17.320         53.510
# total_boosters_per_hundred                         3.820         30.620
# new_vaccinations_smoothed_per_million            168.000        813.000
# new_people_vaccinated_smoothed                    66.000      1,080.000
# new_people_vaccinated_smoothed_per_hundred         0.002          0.019
# stringency_index                                  22.220         42.590
# population_density                                37.728         90.672
# median_age                                        22.200         29.700
# aged_65_older                                      3.526          6.378
# aged_70_older                                      2.085          3.871
# gdp_per_capita                                 3,823.194     12,294.876
# extreme_poverty                                    0.600          2.500
# cardiovasc_death_rate                            175.695        245.063
# diabetes_prevalence                                5.350          7.200
# female_smokers                                     1.900          6.300
# male_smokers                                      22.600         33.100
# handwashing_facilities                            20.859         49.839
# hospital_beds_per_thousand                         1.300          2.500
# life_expectancy                                   69.590         75.050
# human_development_index                            0.602          0.740
# population                                   449,002.000  5,882,259.000
# excess_mortality_cumulative_absolute              49.150      4,878.400
# excess_mortality_cumulative                        0.820          7.910
# excess_mortality                                  -1.430          6.175
# excess_mortality_cumulative_per_million           35.117        964.712
#
#                                                       75%                max
# total_cases                                   648,353.000    768,186,332.000
# new_cases                                         490.000      7,945,885.000
# new_cases_smoothed                                605.000      6,403,052.429
# total_deaths                                   10,198.000      6,945,701.000
# new_deaths                                          5.000         20,042.000
# new_deaths_smoothed                                 6.286         14,674.714
# total_cases_per_million                       112,412.656        737,554.506
# new_cases_per_million                              64.090        228,872.025
# new_cases_smoothed_per_million                     98.432         37,241.781
# total_deaths_per_million                        1,245.716          6,484.454
# new_deaths_per_million                              0.390            603.656
# new_deaths_smoothed_per_million                     0.715            148.641
# reproduction_rate                                   1.140              5.870
# icu_patients                                      446.000         28,891.000
# icu_patients_per_million                           20.854            180.675
# hosp_patients                                   3,103.000        154,497.000
# hosp_patients_per_million                         170.758          1,526.846
# weekly_icu_admissions                             458.000          4,838.000
# weekly_icu_admissions_per_million                  13.985            224.976
# weekly_hosp_admissions                          4,103.250        153,977.000
# weekly_hosp_admissions_per_million                117.970            708.405
# total_tests                                10,248,451.500  9,214,000,000.000
# new_tests                                      37,229.000     35,855,632.000
# total_tests_per_thousand                          894.375         32,925.826
# new_tests_per_thousand                              2.914            531.062
# new_tests_smoothed                             32,205.000     14,769,984.000
# new_tests_smoothed_per_thousand                     2.584            147.603
# positive_rate                                       0.138              1.000
# tests_per_case                                     54.600      1,023,631.900
# total_vaccinations                         84,460,701.250 13,472,986,097.000
# people_vaccinated                          41,355,234.250  5,609,359,281.000
# people_fully_vaccinated                    35,341,428.000  5,155,921,493.000
# total_boosters                             28,235,550.000  2,785,401,153.000
# new_vaccinations                              223,282.000     49,673,461.000
# new_vaccinations_smoothed                      36,922.000     43,692,999.000
# total_vaccinations_per_hundred                    185.970            406.430
# people_vaccinated_per_hundred                      76.840            129.070
# people_fully_vaccinated_per_hundred                72.800            126.890
# total_boosters_per_hundred                         55.900            150.470
# new_vaccinations_smoothed_per_million           2,759.000        117,113.000
# new_people_vaccinated_smoothed                 11,652.000     21,071,253.000
# new_people_vaccinated_smoothed_per_hundred          0.088             11.711
# stringency_index                                   62.040            100.000
# population_density                                222.873         20,546.766
# median_age                                         38.700             48.200
# aged_65_older                                      13.928             27.049
# aged_70_older                                       8.643             18.493
# gdp_per_capita                                 27,216.445        116,935.600
# extreme_poverty                                    21.400             77.600
# cardiovasc_death_rate                             331.932            724.417
# diabetes_prevalence                                10.790             30.530
# female_smokers                                     19.300             44.000
# male_smokers                                       41.300             78.100
# handwashing_facilities                             83.241            100.000
# hospital_beds_per_thousand                          4.200             13.800
# life_expectancy                                    79.460             86.750
# human_development_index                             0.829              0.957
# population                                 28,301,700.000  7,975,105,024.000
# excess_mortality_cumulative_absolute           32,882.250      1,288,358.400
# excess_mortality_cumulative                        15.310             76.550
# excess_mortality                                   17.418            377.370
# excess_mortality_cumulative_per_million         2,519.642         10,292.318

# %%
print(df.isna().sum()/len(df)*100)
# Out:
# iso_code                                      0.000
# continent                                     4.750
# location                                      0.000
# date                                          0.000
# total_cases                                  10.206
# new_cases                                     2.785
# new_cases_smoothed                            3.180
# total_deaths                                 15.972
# new_deaths                                    2.771
# new_deaths_smoothed                           3.155
# total_cases_per_million                      10.206
# new_cases_per_million                         2.785
# new_cases_smoothed_per_million                3.180
# total_deaths_per_million                     15.972
# new_deaths_per_million                        2.771
# new_deaths_smoothed_per_million               3.155
# reproduction_rate                            42.286
# icu_patients                                 88.552
# icu_patients_per_million                     88.552
# hosp_patients                                88.299
# hosp_patients_per_million                    88.299
# weekly_icu_admissions                        96.977
# weekly_icu_admissions_per_million            96.977
# weekly_hosp_admissions                       93.032
# weekly_hosp_admissions_per_million           93.032
# total_tests                                  75.209
# new_tests                                    76.453
# total_tests_per_thousand                     75.209
# new_tests_per_thousand                       76.453
# new_tests_smoothed                           67.534
# new_tests_smoothed_per_thousand              67.534
# positive_rate                                70.044
# tests_per_case                               70.537
# tests_units                                  66.653
# total_vaccinations                           76.203
# people_vaccinated                            77.213
# people_fully_vaccinated                      78.298
# total_boosters                               86.039
# new_vaccinations                             80.418
# new_vaccinations_smoothed                    46.270
# total_vaccinations_per_hundred               76.203
# people_vaccinated_per_hundred                77.213
# people_fully_vaccinated_per_hundred          78.298
# total_boosters_per_hundred                   86.039
# new_vaccinations_smoothed_per_million        46.270
# new_people_vaccinated_smoothed               46.322
# new_people_vaccinated_smoothed_per_hundred   46.322
# stringency_index                             38.278
# population_density                           15.145
# median_age                                   21.080
# aged_65_older                                23.843
# aged_70_older                                21.871
# gdp_per_capita                               22.657
# extreme_poverty                              50.178
# cardiovasc_death_rate                        22.505
# diabetes_prevalence                          18.556
# female_smokers                               41.872
# male_smokers                                 42.663
# handwashing_facilities                       62.043
# hospital_beds_per_thousand                   31.593
# life_expectancy                               8.034
# human_development_index                      24.882
# population                                    0.000
# excess_mortality_cumulative_absolute         96.537
# excess_mortality_cumulative                  96.537
# excess_mortality                             96.537
# excess_mortality_cumulative_per_million      96.537
# dtype: float64

# %%
df.shape
# Out:
# (320229, 67)

# %% [markdown]
# Просмотрев статистику по датафрейму, можно сказать, что выборка имеет размерность 67 на 314880, много столбцов содержат большое количество пропусков и выбросов, а также присутствует 5 столбцов типа object (остальные float)

# %% [markdown]
# ### Удаление столбцов с большим количеством пропусков

# %%
for i in df:
    if (df[i].isna().sum()/len(df)*100 > 35):
        df.drop(columns=i, inplace = True)

# %%
print(df.isna().sum()/len(df)*100)
# Out:
# iso_code                           0.000
# continent                          4.750
# location                           0.000
# date                               0.000
# total_cases                       10.206
# new_cases                          2.785
# new_cases_smoothed                 3.180
# total_deaths                      15.972
# new_deaths                         2.771
# new_deaths_smoothed                3.155
# total_cases_per_million           10.206
# new_cases_per_million              2.785
# new_cases_smoothed_per_million     3.180
# total_deaths_per_million          15.972
# new_deaths_per_million             2.771
# new_deaths_smoothed_per_million    3.155
# population_density                15.145
# median_age                        21.080
# aged_65_older                     23.843
# aged_70_older                     21.871
# gdp_per_capita                    22.657
# cardiovasc_death_rate             22.505
# diabetes_prevalence               18.556
# hospital_beds_per_thousand        31.593
# life_expectancy                    8.034
# human_development_index           24.882
# population                         0.000
# dtype: float64

# %%
df.describe().T
# Out:
#                                       count            mean             std  \
# total_cases                     287,547.000   5,915,161.456  36,974,255.273
# new_cases                       311,310.000      10,458.979     101,536.916
# new_cases_smoothed              310,046.000      10,499.898      98,821.554
# total_deaths                    269,083.000      80,069.501     417,655.013
# new_deaths                      311,356.000          93.273         592.540
# new_deaths_smoothed             310,126.000          93.623         583.245
# total_cases_per_million         287,547.000      90,271.593     141,358.080
# new_cases_per_million           311,310.000         158.007       1,116.844
# new_cases_smoothed_per_million  310,046.000         158.629         626.056
# total_deaths_per_million        269,083.000         807.831       1,060.239
# new_deaths_per_million          311,356.000           0.990           4.622
# new_deaths_smoothed_per_million 310,126.000           0.993           2.877
# population_density              271,730.000         409.340       1,866.756
# median_age                      252,725.000          30.510           9.084
# aged_65_older                   243,878.000           8.700           6.094
# aged_70_older                   250,193.000           5.500           4.135
# gdp_per_capita                  247,675.000      19,006.955      19,984.743
# cardiovasc_death_rate           248,160.000         264.271         120.928
# diabetes_prevalence             260,807.000           8.561           4.941
# hospital_beds_per_thousand      219,058.000           3.097           2.548
# life_expectancy                 294,503.000          73.718           7.397
# human_development_index         240,549.000           0.722           0.149
# population                      320,229.000 128,186,736.682 659,921,726.119
#
#                                     min         25%           50%  \
# total_cases                       1.000   6,359.500    61,775.000
# new_cases                         0.000       0.000        14.000
# new_cases_smoothed                0.000       0.857        35.000
# total_deaths                      1.000     113.000     1,111.000
# new_deaths                        0.000       0.000         0.000
# new_deaths_smoothed               0.000       0.000         0.286
# total_cases_per_million           0.000   1,949.844    21,229.570
# new_cases_per_million             0.000       0.000         1.988
# new_cases_smoothed_per_million    0.000       0.192         9.643
# total_deaths_per_million          0.000      43.739       328.203
# new_deaths_per_million            0.000       0.000         0.000
# new_deaths_smoothed_per_million   0.000       0.000         0.027
# population_density                0.137      37.728        90.672
# median_age                       15.100      22.200        29.700
# aged_65_older                     1.144       3.526         6.378
# aged_70_older                     0.526       2.085         3.871
# gdp_per_capita                  661.240   3,823.194    12,294.876
# cardiovasc_death_rate            79.370     175.695       245.063
# diabetes_prevalence               0.990       5.350         7.200
# hospital_beds_per_thousand        0.100       1.300         2.500
# life_expectancy                  53.280      69.590        75.050
# human_development_index           0.394       0.602         0.740
# population                       47.000 449,002.000 5,882,259.000
#
#                                            75%               max
# total_cases                        648,353.000   768,186,332.000
# new_cases                              490.000     7,945,885.000
# new_cases_smoothed                     605.000     6,403,052.429
# total_deaths                        10,198.000     6,945,701.000
# new_deaths                               5.000        20,042.000
# new_deaths_smoothed                      6.286        14,674.714
# total_cases_per_million            112,412.656       737,554.506
# new_cases_per_million                   64.090       228,872.025
# new_cases_smoothed_per_million          98.432        37,241.781
# total_deaths_per_million             1,245.716         6,484.454
# new_deaths_per_million                   0.390           603.656
# new_deaths_smoothed_per_million          0.715           148.641
# population_density                     222.873        20,546.766
# median_age                              38.700            48.200
# aged_65_older                           13.928            27.049
# aged_70_older                            8.643            18.493
# gdp_per_capita                      27,216.445       116,935.600
# cardiovasc_death_rate                  331.932           724.417
# diabetes_prevalence                     10.790            30.530
# hospital_beds_per_thousand               4.200            13.800
# life_expectancy                         79.460            86.750
# human_development_index                  0.829             0.957
# population                      28,301,700.000 7,975,105,024.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320229 entries, 0 to 320228
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   iso_code                         320229 non-null  object
#  1   continent                        305019 non-null  object
#  2   location                         320229 non-null  object
#  3   date                             320229 non-null  datetime64[ns]
#  4   total_cases                      287547 non-null  float64
#  5   new_cases                        311310 non-null  float64
#  6   new_cases_smoothed               310046 non-null  float64
#  7   total_deaths                     269083 non-null  float64
#  8   new_deaths                       311356 non-null  float64
#  9   new_deaths_smoothed              310126 non-null  float64
#  10  total_cases_per_million          287547 non-null  float64
#  11  new_cases_per_million            311310 non-null  float64
#  12  new_cases_smoothed_per_million   310046 non-null  float64
#  13  total_deaths_per_million         269083 non-null  float64
#  14  new_deaths_per_million           311356 non-null  float64
#  15  new_deaths_smoothed_per_million  310126 non-null  float64
#  16  population_density               271730 non-null  float64
#  17  median_age                       252725 non-null  float64
#  18  aged_65_older                    243878 non-null  float64
#  19  aged_70_older                    250193 non-null  float64
#  20  gdp_per_capita                   247675 non-null  float64
#  21  cardiovasc_death_rate            248160 non-null  float64
#  22  diabetes_prevalence              260807 non-null  float64
#  23  hospital_beds_per_thousand       219058 non-null  float64
#  24  life_expectancy                  294503 non-null  float64
#  25  human_development_index          240549 non-null  float64
#  26  population                       320229 non-null  float64
# dtypes: datetime64[ns](1), float64(23), object(3)
# memory usage: 66.0+ MB

# %% [markdown]
# ###

# %%
df.dropna(subset=["total_cases"], inplace = True) #удаление NaN значений в столбце total_cases

# %%
df.dropna(subset=["new_cases"], inplace = True) #удаление NaN значений в столбце new_cases

# %% [markdown]
# Было осуществлено очищение столбцов total_cases и new_cases от NaN значений, так как я посчитал, что информация в данных столбцах представляет ценность для обучения модели и отражает краткую и емкую характеристику эпидемологической ситуации в странах

# %% [markdown]
# ### Вычисление коэффициента заболеваемости Rt для каждого дня в выборке

# %%
df['new_cases_4days_avg'] = df['new_cases'].rolling(window=4).mean()

# Вычисление скользящего среднего числа заболевших за предыдущие 4 дня
df['prev_new_cases_4days_avg'] = df['new_cases'].shift(4).rolling(window=4).mean()

# Вычисление коэффициента Rt
df['Rt'] = df['new_cases_4days_avg'] / df['prev_new_cases_4days_avg']

# %%
df.loc[df["Rt"] > 1.5]
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 66          AFG      Asia  Afghanistan 2020-03-09        4.000      3.000
# 67          AFG      Asia  Afghanistan 2020-03-10        4.000      0.000
# 68          AFG      Asia  Afghanistan 2020-03-11        4.000      0.000
# 69          AFG      Asia  Afghanistan 2020-03-12        7.000      3.000
# 74          AFG      Asia  Afghanistan 2020-03-17       16.000      6.000
# ...         ...       ...          ...        ...          ...        ...
# 320210      ZWE    Africa     Zimbabwe 2023-06-03  265,139.000     32.000
# 320219      ZWE    Africa     Zimbabwe 2023-06-12  265,289.000    128.000
# 320220      ZWE    Africa     Zimbabwe 2023-06-13  265,289.000      0.000
# 320221      ZWE    Africa     Zimbabwe 2023-06-14  265,289.000      0.000
# 320222      ZWE    Africa     Zimbabwe 2023-06-15  265,289.000      0.000
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 66                   0.429           NaN       0.000                0.000
# 67                   0.429           NaN       0.000                0.000
# 68                   0.429           NaN       0.000                0.000
# 69                   0.857           NaN       0.000                0.000
# 74                   1.714           NaN       0.000                0.000
# ...                    ...           ...         ...                  ...
# 320210              21.000     5,695.000       0.000                0.429
# 320219              18.286     5,702.000       7.000                1.000
# 320220              18.286     5,702.000       0.000                1.000
# 320221              18.286     5,702.000       0.000                1.000
# 320222              18.286     5,702.000       0.000                1.000
#
#         ...  gdp_per_capita  cardiovasc_death_rate  diabetes_prevalence  \
# 66      ...       1,803.987                597.029                9.590
# 67      ...       1,803.987                597.029                9.590
# 68      ...       1,803.987                597.029                9.590
# 69      ...       1,803.987                597.029                9.590
# 74      ...       1,803.987                597.029                9.590
# ...     ...             ...                    ...                  ...
# 320210  ...       1,899.775                307.846                1.820
# 320219  ...       1,899.775                307.846                1.820
# 320220  ...       1,899.775                307.846                1.820
# 320221  ...       1,899.775                307.846                1.820
# 320222  ...       1,899.775                307.846                1.820
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 66                           0.500           64.830                    0.511
# 67                           0.500           64.830                    0.511
# 68                           0.500           64.830                    0.511
# 69                           0.500           64.830                    0.511
# 74                           0.500           64.830                    0.511
# ...                            ...              ...                      ...
# 320210                       1.700           61.490                    0.571
# 320219                       1.700           61.490                    0.571
# 320220                       1.700           61.490                    0.571
# 320221                       1.700           61.490                    0.571
# 320222                       1.700           61.490                    0.571
#
#            population  new_cases_4days_avg  prev_new_cases_4days_avg     Rt
# 66     41,128,772.000                0.750                     0.000    inf
# 67     41,128,772.000                0.750                     0.000    inf
# 68     41,128,772.000                0.750                     0.000    inf
# 69     41,128,772.000                1.500                     0.000    inf
# 74     41,128,772.000                2.250                     0.750  3.000
# ...               ...                  ...                       ...    ...
# 320210 16,320,539.000               27.250                     9.500  2.868
# 320219 16,320,539.000               32.000                     2.250 14.222
# 320220 16,320,539.000               32.000                     0.000    inf
# 320221 16,320,539.000               32.000                     0.000    inf
# 320222 16,320,539.000               32.000                     0.000    inf
#
# [57215 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287421 entries, 54 to 320226
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   iso_code                         287421 non-null  object
#  1   continent                        272332 non-null  object
#  2   location                         287421 non-null  object
#  3   date                             287421 non-null  datetime64[ns]
#  4   total_cases                      287421 non-null  float64
#  5   new_cases                        287421 non-null  float64
#  6   new_cases_smoothed               287151 non-null  float64
#  7   total_deaths                     268983 non-null  float64
#  8   new_deaths                       287376 non-null  float64
#  9   new_deaths_smoothed              287140 non-null  float64
#  10  total_cases_per_million          287421 non-null  float64
#  11  new_cases_per_million            287421 non-null  float64
#  12  new_cases_smoothed_per_million   287151 non-null  float64
#  13  total_deaths_per_million         268983 non-null  float64
#  14  new_deaths_per_million           287376 non-null  float64
#  15  new_deaths_smoothed_per_million  287140 non-null  float64
#  16  population_density               251678 non-null  float64
#  17  median_age                       235437 non-null  float64
#  18  aged_65_older                    228264 non-null  float64
#  19  aged_70_older                    233040 non-null  float64
#  20  gdp_per_capita                   230737 non-null  float64
#  21  cardiovasc_death_rate            232237 non-null  float64
#  22  diabetes_prevalence              242747 non-null  float64
#  23  hospital_beds_per_thousand       205625 non-null  float64
#  24  life_expectancy                  268461 non-null  float64
#  25  human_development_index          226327 non-null  float64
#  26  population                       287421 non-null  float64
#  27  new_cases_4days_avg              287418 non-null  float64
#  28  prev_new_cases_4days_avg         287414 non-null  float64
#  29  Rt                               251659 non-null  float64
# dtypes: datetime64[ns](1), float64(26), object(3)
# memory usage: 68.0+ MB

# %%
df.dropna(subset=["Rt"], inplace = True) #удаление NaN значений в столбце Rt

# %% [markdown]
# ### Удаление лишних столбцов

# %%
df = df[["Rt","new_cases","total_cases","date","location"]] #оставляем для кластеризации 3 столбца

# %%
df
# Out:
#           Rt  new_cases  total_cases       date     location
# 61     0.000      0.000        1.000 2020-03-04  Afghanistan
# 66       inf      3.000        4.000 2020-03-09  Afghanistan
# 67       inf      0.000        4.000 2020-03-10  Afghanistan
# 68       inf      0.000        4.000 2020-03-11  Afghanistan
# 69       inf      3.000        7.000 2020-03-12  Afghanistan
# ...      ...        ...          ...        ...          ...
# 320222   inf      0.000  265,289.000 2023-06-15     Zimbabwe
# 320223 0.000      0.000  265,289.000 2023-06-16     Zimbabwe
# 320224 0.000      0.000  265,289.000 2023-06-17     Zimbabwe
# 320225 0.000      0.000  265,289.000 2023-06-18     Zimbabwe
# 320226 0.969    124.000  265,413.000 2023-06-19     Zimbabwe
#
# [251659 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251659 entries, 61 to 320226
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Rt           251659 non-null  float64
#  1   new_cases    251659 non-null  float64
#  2   total_cases  251659 non-null  float64
#  3   date         251659 non-null  datetime64[ns]
#  4   location     251659 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 11.5+ MB

# %%
df.describe().T
# Out:
#                   count          mean            std   min       25%  \
# Rt          251,659.000           inf            NaN 0.000     0.701
# new_cases   251,659.000    12,938.082    112,789.228 0.000     1.000
# total_cases 251,659.000 6,700,133.038 39,435,392.036 1.000 9,089.000
#
#                    50%         75%             max
# Rt               1.000       1.422             inf
# new_cases       62.000     903.000   7,945,885.000
# total_cases 88,783.000 830,997.000 768,186,332.000

# %% [markdown]
# В столбцах присутствуют выбросы, а столбец Rt содержит значение inf, поэтому необходимо оставить лишь корректные данные

# %%
#убираем выбросы
quant = df["Rt"].quantile(0.9)# считаем квантиль 90 %
quant_low = df["Rt"].quantile(0.01)# считаем квантиль 1 %
df = df[df["Rt"] < quant] # убираем выбросы по квантилю
df = df[df["Rt"] > quant_low] # убираем выбросы по квантилю

# %%
df.describe().T
# Out:
#                   count          mean            std   min        25%  \
# Rt          204,166.000         1.123          0.675 0.000      0.760
# new_cases   204,166.000    15,895.338    124,939.356 0.000     14.000
# total_cases 204,166.000 7,858,140.096 43,362,829.233 1.000 11,491.250
#
#                     50%           75%             max
# Rt                0.993         1.277           5.892
# new_cases       166.000     1,514.000   7,945,885.000
# total_cases 128,635.000 1,006,099.250 768,186,332.000

# %%
df["Rt"].quantile(0.9)
# Out:
# 1.7852000611228027

# %%
# import math
# df.loc[df["Rt"] == math.inf, "Rt"] = 0 #меняем значения inf на 0

df_for_learn = df[["Rt","new_cases","total_cases"]]

# %% [markdown]
# Значения inf и выбросы были удалены из выборки

# %% [markdown]
# # Подбор оптимальных параметров модели

# %%
#выполняем подбор оптимального значения параметра модели путем сравнения метрики измерения качества кластеризации (Kmeans Inertia)
from sklearn.cluster import KMeans #библиотека алгоритма машинного обучения для кластеризации данных

inertias = []
max_num_clusters = 10
for k in range(1, max_num_clusters + 1):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_for_learn)
    inertias.append(kmeans.inertia_)

# Визуализация графика "Локоть"
plt.plot(range(1, max_num_clusters + 1), inertias, marker='o')
plt.xlabel("Количество кластеров")
plt.ylabel("Inertia")
plt.title("Метод локтя на определение оптимального 'k'")
plt.show()

# %% [markdown]
# Видно разделение датафрейма на 3 кластера

# %% [markdown]
# # Обучение модели K-means

# %%
#обучаем модель на трех кластерах
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit_predict(df_for_learn)

# %%
#график распределения точек по кластерам
plt.scatter(df_for_learn['Rt'], df_for_learn['total_cases'], c=clusters, s=50, cmap='viridis')
plt.show()

# %% [markdown]
# Таким образом, путем выведение нового коэффициента и алгоритма кластеризации "k-средние", получилось разбить выборку на три кластера

# %%
df_for_learn
# Out:
#           Rt  new_cases  total_cases
# 70     1.000      0.000        7.000
# 71     1.000      0.000        7.000
# 72     1.000      0.000        7.000
# 73     0.500      3.000       10.000
# 74     3.000      6.000       16.000
# ...      ...        ...          ...
# 320212 1.123      9.000  265,161.000
# 320213 0.701      0.000  265,161.000
# 320214 0.202      0.000  265,161.000
# 320215 0.115      0.000  265,161.000
# 320226 0.969    124.000  265,413.000
#
# [204166 rows x 3 columns]

# %%
df
# Out:
#           Rt  new_cases  total_cases       date     location
# 70     1.000      0.000        7.000 2020-03-13  Afghanistan
# 71     1.000      0.000        7.000 2020-03-14  Afghanistan
# 72     1.000      0.000        7.000 2020-03-15  Afghanistan
# 73     0.500      3.000       10.000 2020-03-16  Afghanistan
# 74     3.000      6.000       16.000 2020-03-17  Afghanistan
# ...      ...        ...          ...        ...          ...
# 320212 1.123      9.000  265,161.000 2023-06-05     Zimbabwe
# 320213 0.701      0.000  265,161.000 2023-06-06     Zimbabwe
# 320214 0.202      0.000  265,161.000 2023-06-07     Zimbabwe
# 320215 0.115      0.000  265,161.000 2023-06-08     Zimbabwe
# 320226 0.969    124.000  265,413.000 2023-06-19     Zimbabwe
#
# [204166 rows x 5 columns]

# %%
# len(df['location'].unique())

# for country in df['location'].unique():
#     df.loc[(df['location'] == country) & ((df['date'] - datetime.datetime.now()).abs().argsort()[0])]

df_sorted = df.sort_values(by="date", inplace=False)
last_entries = df.groupby("location").last()
last_entries
# Out:
#                                     Rt   new_cases     total_cases       date
# location
# Afghanistan                      0.144       0.000     222,954.000 2023-06-21
# Africa                           0.249       0.000  13,096,524.000 2023-06-21
# Albania                          0.195       0.000     334,090.000 2023-04-22
# Algeria                          1.000       0.000     271,841.000 2023-06-05
# American Samoa                   2.000       2.000       8,329.000 2023-04-10
# Andorra                          1.414      41.000      48,015.000 2023-05-04
# Angola                           3.444      31.000     105,384.000 2023-04-18
# Anguilla                         0.143       0.000       3,866.000 2022-10-06
# Antigua and Barbuda              0.111       0.000       9,098.000 2022-09-30
# Argentina                        1.018     832.000  10,044,957.000 2023-03-05
# Armenia                          0.900       9.000     449,222.000 2023-06-11
# Aruba                            1.875      15.000      44,114.000 2023-03-29
# Asia                             3.127 130,194.000 298,126,479.000 2023-06-19
# Australia                        0.743  23,290.000  11,477,838.000 2023-06-12
# Austria                          0.495       0.000   6,080,088.000 2023-06-21
# Azerbaijan                       0.875       0.000     831,896.000 2023-06-21
# Bahamas                          0.158      81.000      38,084.000 2023-04-23
# Bahrain                          0.194       0.000     696,614.000 2022-12-07
# Bangladesh                       1.325     153.000   2,041,623.000 2023-06-19
# Barbados                         2.280     228.000     107,794.000 2023-05-14
# Belarus                          0.037       0.000     982,867.000 2022-05-14
# Belgium                          0.254       0.000   4,800,759.000 2023-06-18
# Belize                           0.895      17.000      70,757.000 2023-03-01
# Benin                            1.000       1.000      28,014.000 2023-03-27
# Bermuda                          1.625       0.000      18,849.000 2023-03-24
# Bhutan                           1.000       1.000      62,672.000 2023-06-04
# Bolivia                          1.504   1,143.000   1,201,597.000 2023-06-18
# Bonaire Sint Eustatius and Saba  1.086      38.000      11,885.000 2023-04-02
# Bosnia and Herzegovina           0.344      11.000     403,041.000 2023-06-12
# Botswana                         1.095      23.000     329,985.000 2023-06-11
# Brazil                           0.544  13,408.000  37,639,324.000 2023-06-18
# British Virgin Islands           0.087      14.000       7,305.000 2022-09-07
py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_for_learn["cluster"] = clusters

# %%
df_for_learn['cluster'].value_counts()
# Out:
# 0    199116
# 2      4221
# 1       829
# Name: cluster, dtype: int64

# %%
df_for_learn.describe()
# Out:
#                Rt     new_cases     total_cases     cluster
# count 204,166.000   204,166.000     204,166.000 204,166.000
# mean        1.123    15,895.338   7,858,140.096       0.045
# std         0.675   124,939.356  43,362,829.233       0.291
# min         0.000         0.000           1.000       0.000
# 25%         0.760        14.000      11,491.250       0.000
# 50%         0.993       166.000     128,635.000       0.000
# 75%         1.277     1,514.000   1,006,099.250       0.000
# max         5.892 7,945,885.000 768,186,332.000       2.000

# %%
df_for_learn["Rt"].quantile(0.95)
# Out:
# 2.3333333333333335

# %%
quantile_75 = df_for_learn["Rt"].quantile(0.75)
quantile_90 = df_for_learn["Rt"].quantile(0.9)

def f(row):
    val = 0
    if row['Rt'] < quantile_75:
        val = 0
    elif (row['Rt'] > quantile_75) and (row['Rt'] < quantile_90):
        val = 1
    elif (row['Rt'] > quantile_90):
        val = 2
    return val

df_for_learn['quantile_cluster'] = df_for_learn.apply (f, axis=1)

# %%
df['quantile_cluster'] = df_for_learn['quantile_cluster']

# %%
df_sorted = df.sort_values(by="date", inplace=False)
last_entries = df.groupby("location").last().reset_index()
last_entries

json_list = []

# Перебираем строки DataFrame
for index, row in last_entries.iterrows():
    # Создаем словарь с ключом из первого столбца и значением из второго столбца
    obj = {"country": row['location'], "cluster": row['quantile_cluster']}
    # Добавляем словарь в список объектов JSON
    json_list.append(obj)

# Преобразуем список объектов JSON в JSON-массив
json_array = json.dumps(json_list)

# print(json.loads(json_array))
with open("data.json", "w") as f:
    json.dump(json_array, f)

# %%
json_list = [{"123":"123"}, {"345":"345"}]

json_array = json.dumps(json_list)

with open("data1.json", "w") as f:
    json.dump(json_array, f)

# %%
df
# Out:
#           Rt  new_cases  total_cases       date     location  quantile_cluster
# 70     1.000      0.000        7.000 2020-03-13  Afghanistan                 0
# 71     1.000      0.000        7.000 2020-03-14  Afghanistan                 0
# 72     1.000      0.000        7.000 2020-03-15  Afghanistan                 0
# 73     0.500      3.000       10.000 2020-03-16  Afghanistan                 0
# 74     3.000      6.000       16.000 2020-03-17  Afghanistan                 2
# ...      ...        ...          ...        ...          ...               ...
# 320212 1.123      9.000  265,161.000 2023-06-05     Zimbabwe                 0
# 320213 0.701      0.000  265,161.000 2023-06-06     Zimbabwe                 0
# 320214 0.202      0.000  265,161.000 2023-06-07     Zimbabwe                 0
# 320215 0.115      0.000  265,161.000 2023-06-08     Zimbabwe                 0
# 320226 0.969    124.000  265,413.000 2023-06-19     Zimbabwe                 0
#
# [204166 rows x 6 columns]

# %%
df_for_learn['quantile_cluster'].value_counts()
# Out:
# 0    153124
# 1     30625
# 2     20417
# Name: quantile_cluster, dtype: int64

# %%
df_for_learn[:50]
# Out:
#        Rt  new_cases  total_cases  cluster  quantile_cluster
# 70  1.000      0.000        7.000        0                 0
# 71  1.000      0.000        7.000        0                 0
# 72  1.000      0.000        7.000        0                 0
# 88  0.800      8.000      114.000 2020-03-31  Afghanistan                 0
# 89  2.150     52.000      166.000 2020-04-01  Afghanistan                 2
# 90  2.061     26.000      192.000 2020-04-02  Afghanistan                 2
# 91  2.750      2.000      194.000 2020-04-03  Afghanistan                 2
# 92  3.500     60.000      254.000 2020-04-04  Afghanistan                 2
# 93  1.256     20.000      274.000 2020-04-05  Afghanistan                 0
# 94  1.059     25.000      299.000 2020-04-06  Afghanistan                 0
# 95  1.625     38.000      337.000 2020-04-07  Afghanistan                 1
# 96  0.807     30.000      367.000 2020-04-08  Afghanistan                 0
# 97  1.380     56.000      423.000 2020-04-09  Afghanistan                 1
# 98  1.355     21.000      444.000 2020-04-10  Afghanistan                 1
# 99  1.028     40.000      484.000 2020-04-11  Afghanistan                 0
# 100 1.363     37.000      521.000 2020-04-12  Afghanistan                 1
# 101 0.886     34.000      555.000 2020-04-13  Afghanistan                 0
# 102 1.124     52.000      607.000 2020-04-14  Afghanistan                 0
# 103 1.231     58.000      665.000 2020-04-15  Afghanistan                 0
# 104 1.299     56.000      721.000 2020-04-16  Afghanistan                 1
# 105 1.811     73.000      794.000 2020-04-17  Afghanistan                 2
# 106 1.460     51.000      845.000 2020-04-18  Afghanistan                 1
# 107 1.343     63.000      908.000 2020-04-19  Afghanistan                 1
# 108 1.060     25.000      933.000 2020-04-20  Afghanistan                 0
# 109 0.845     63.000      996.000 2020-04-21  Afghanistan                 0
# 110 0.761     30.000    1,026.000 2020-04-22  Afghanistan                 0
# 111 0.757     66.000    1,092.000 2020-04-23  Afghanistan                 0
# 112 1.146     84.000    1,176.000 2020-04-24  Afghanistan                 0
# 113 1.139     50.000    1,226.000 2020-04-25  Afghanistan                 0
# 114 1.680    104.000    1,330.000 2020-04-26  Afghanistan                 1
# 115 2.016    133.000    1,463.000 2020-04-27  Afghanistan                 2
# 116 1.461     68.000    1,531.000 2020-04-28  Afghanistan                 1
# 117 2.074    172.000    1,703.000 2020-04-29  Afghanistan                 2
# 118 1.635    124.000    1,827.000 2020-04-30  Afghanistan                 1
# 119 1.278    110.000    1,937.000 2020-05-01  Afghanistan                 1
# 120 1.803    234.000    2,171.000 2020-05-02  Afghanistan                 2
# 121 0.981      0.000    2,171.000 2020-05-03  Afghanistan                 0

# %%
quantile_clusters = df_for_learn[['quantile_cluster']].to_numpy()

# %%
len(quantile_clusters)
# Out:
# 204166

# %%
df_for_learn.drop(columns=["cluster"], inplace=True)

# %%
#выполняем подбор оптимального значения параметра модели путем сравнения метрики измерения качества кластеризации (Kmeans Inertia)
from sklearn.cluster import KMeans #библиотека алгоритма машинного обучения для кластеризации данных

inertias = []
max_num_clusters = 10
for k in range(1, max_num_clusters + 1):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df_for_learn)
    inertias.append(kmeans.inertia_)

# Визуализация графика "Локоть"
plt.plot(range(1, max_num_clusters + 1), inertias, marker='o')
plt.xlabel("Количество кластеров")
plt.ylabel("Inertia")
plt.title("Метод локтя на определение оптимального 'k'")
plt.show()

# %%
#график распределения точек по кластерам
plt.scatter(df_for_learn['Rt'], df_for_learn['total_cases'], c=quantile_clusters, s=50, cmap='viridis')
plt.show()
